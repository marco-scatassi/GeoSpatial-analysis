# %% [markdown]
# ## Import

# %%
import sys

sys.path.append(r'C:\Users\Marco\Documents\GitHub\GeoSpatial-analysis\facility-location-Bergen\src\facility_location_Bergen\custome_modules')

# %%
# Get the database using the method we defined in pymongo_test_insert file
import os
import pytz
import copy
import json
import geojson
import numpy as np
import pandas as pd
from dateutil import parser
from pymongo import database
from get_api_call_time import get_api_call_time
from geojson import GeometryCollection, LineString
from kedro.extras.datasets.json import JSONDataSet
from mongo_db import retrieve_database_and_collections, take_empty_collections

# %% [markdown]
# ## Connect to MongoDB

# %% [markdown]
# ### Retrieve the database and the collection

# %% [markdown]
# Defing the database and the collections names

# %%
days = "20_04_2023"
db_name = "facility_location_Bergen"

# %%
db, collections = retrieve_database_and_collections(db_name, days, ["raw", "processed"])
empty_collections = take_empty_collections(collections)

# %%
empty_collections
# Out:
# {}

# %% [markdown]
# ### Insert documents in the collections

# %%
root_dir = r"C:\Users\Marco\Documents\GitHub\GeoSpatial-analysis\facility-location-Bergen\data\01_raw\Bergen"

# %%
def compose_url_to_raw_data(db_name: str, day: str, root_dir: str):
    # retrieve database and collections wrappers
    db, collections = retrieve_database_and_collections(db_name, day, ["raw", "processed"])
    empty_collections = take_empty_collections(collections)
    # check if the number of empty collections is not more than 2
    if len(empty_collections) > 2:
        raise ValueError("No more than one date can be processed at a time, please select only one new date.")
    # compose the urls to the raw data
    day_ = np.unique([key[-10:] for key in empty_collections.keys()])
    # check if the day_ is not empty
    if len(day_) == 0:
        return []
    dirs = [dir for dir in os.listdir(root_dir+f"\\{day_[0]}") if dir[:10] in day_]
    dirs_urls = [os.path.join(root_dir+f"\\{day_[0]}", dir) for dir in dirs]
    file_urls = [os.path.join(dir_url, file) for dir_url in dirs_urls for file in os.listdir(dir_url)]
    return file_urls

# %% [markdown]
# Compose the url of the raw json

# %%
urls = compose_url_to_raw_data(db_name, days, root_dir)

# %%
def from_urls_to_JSONDataSet(urls: list):
    JSONDataSets = []
    for url in urls:
        JSONDataSets.append(JSONDataSet(filepath=url))
    return JSONDataSets

# %%
def load_raw_data(urls: list):
    raw_data = {}
    JSONDataSets = from_urls_to_JSONDataSet(urls)
    
    for url, json in zip(urls, JSONDataSets):
        if "afternoon" in url:
            key = url[-41:].removesuffix(".json")
        elif "midday" in url:
            key = url[-38:].removesuffix(".json")
        elif "morning" in url:
            key = url[-39:].removesuffix(".json")
            
        raw_data[key] = json.load()
    
    return raw_data

# %% [markdown]
# Load the json file

# %%
raw_data = load_raw_data(urls)

# %%
raw_data
# Out:
# {}

# %%
def get_time_from_raw_data(raw_data: dict):
    times = {}
    for key, value in raw_data.items():
        times[key] = get_api_call_time(key)
    return times

# %%
def splitting_and_time_processing(raw_data: dict):
    time_processed_collections_documents = []
    api_call_times = get_time_from_raw_data(raw_data)
    
    for key, value in raw_data.items():
        dt = parser.parse(value["sourceUpdated"])
        
        for result in value["results"]:
            time_processed_collections_documents.append(result)
            time_processed_collections_documents[-1]["sourceUpdated"] = dt  
            time_processed_collections_documents[-1]["api_call_time"] = api_call_times[key] 
        
    return time_processed_collections_documents

# %%
def geometry_processing(input_data: list):
    geo_processed_data = []
    
    for doc in input_data:
        geo_processed_data.append(doc)
        # extract the links field from the input data
        raw_data_links = doc['location']['shape']['links']
        # create the geometry field (in order to comply the geojson format)
        geo_processed_data[-1]["geometry"] = GeometryCollection(
            [LineString([(e['lng'],e['lat']) for e in i['points']])for i in raw_data_links])
        # create the geometry_length field
        geo_processed_data[-1]["geometry_length"] = [i['length'] for i in raw_data_links]
        # bring embedded fields to the top level
        for k in geo_processed_data[-1]['location']:
            geo_processed_data[-1][k] = geo_processed_data[-1]['location'][k]
            
        # remove duplicated fields    
        geo_processed_data[-1].pop('location')
        geo_processed_data[-1].pop('shape')
        
    return geo_processed_data

# %%
def process_raw_data(urls: list):
    # load the raw data
    raw_data =  load_raw_data(urls)
    time_processed_collections_documents = splitting_and_time_processing(raw_data)
    processed_collections_documents = geometry_processing(time_processed_collections_documents)
    return processed_collections_documents

# %% [markdown]
# Process raw data

# %%
processed_data = process_raw_data(urls)

# %%
processed_data
# Out:
# [{'currentFlow': {'speed': 13.611112,
#    'speedUncapped': 13.611112,
#    'freeFlow': 15.555556,
#    'jamFactor': 1.1,
#    'confidence': 0.87,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.32776, 60.47125], [5.32768, 60.47128], [5.32753, 60.47133]], "type": "LineString"}, {"coordinates": [[5.32753, 60.47133], [5.32742, 60.47136], [5.32734, 60.47138], [5.32715, 60.47142]], "type": "LineString"}, {"coordinates": [[5.32715, 60.47142], [5.32684, 60.47152], [5.32663, 60.47159], [5.32643, 60.47166], [5.32624, 60.47173]], "type": "LineString"}, {"coordinates": [[5.32624, 60.47173], [5.32617, 60.47176]], "type": "LineString"}, {"coordinates": [[5.32617, 60.47176], [5.32603, 60.47182], [5.32586, 60.4719], [5.32567, 60.472]], "type": "LineString"}, {"coordinates": [[5.32567, 60.472], [5.32552, 60.47208], [5.32521, 60.47225]], "type": "LineString"}, {"coordinates": [[5.32521, 60.47225], [5.32504, 60.47235], [5.32483, 60.47249], [5.32465, 60.47261], [5.32449, 60.47271], [5.32432, 60.47282]], "type": "LineString"}, {"coordinates": [[5.32432, 60.47282], [5.32405, 60.47294]], "type": "LineString"}, {"coordinates": [[5.32405, 60.47294], [5.32372, 60.47308], [5.32354, 60.47317], [5.32336, 60.47327], [5.32319, 60.47338], [5.32284, 60.47363]], "type": "LineString"}, {"coordinates": [[5.32284, 60.47363], [5.32246, 60.47391], [5.32229, 60.47403], [5.32219, 60.47409]], "type": "LineString"}, {"coordinates": [[5.32219, 60.47409], [5.32212, 60.47414], [5.32193, 60.47424], [5.3217, 60.47434], [5.32094, 60.47463], [5.32076, 60.47471], [5.32059, 60.4748], [5.32043, 60.47491]], "type": "LineString"}, {"coordinates": [[5.32043, 60.47491], [5.32031, 60.47502], [5.32009, 60.47526], [5.31996, 60.47539], [5.31981, 60.47551], [5.31966, 60.47562], [5.31949, 60.47573], [5.31914,
.22522, 60.36971], [5.22531, 60.36973], [5.22541, 60.36975]], "type": "LineString"}, {"coordinates": [[5.22541, 60.36975], [5.22546, 60.36974]], "type": "LineString"}, {"coordinates": [[5.22546, 60.36974], [5.22553, 60.3697], [5.22559, 60.36965], [5.22566, 60.36957]], "type": "LineString"}, {"coordinates": [[5.22566, 60.36957], [5.22572, 60.36942], [5.22574, 60.36938], [5.2258, 60.36927], [5.22582, 60.36924], [5.22587, 60.36913], [5.22592, 60.36903]], "type": "LineString"}, {"coordinates": [[5.22592, 60.36903], [5.22593, 60.36895], [5.22591, 60.36885]], "type": "LineString"}, {"coordinates": [[5.22591, 60.36885], [5.22589, 60.36882]], "type": "LineString"}, {"coordinates": [[5.22589, 60.36882], [5.22589, 60.36879], [5.22592, 60.36876], [5.22597, 60.36873], [5.22603, 60.36871], [5.22612, 60.3687]], "type": "LineString"}, {"coordinates": [[5.22612, 60.3687], [5.2262, 60.36871]], "type": "LineString"}, {"coordinates": [[5.2262, 60.36871], [5.22625, 60.36873], [5.2263, 60.36876], [5.22632, 60.36879]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [52.0,
#    18.0,
#    21.0,
#    6.0,
#    4.0,
#    7.0,
#    28.0,
#    55.0,
#    63.0,
#    12.0,
#    83.0,
#    318.0,
#    110.0,
#    32.0,
#    16.0,
#    11.0,
#    3.0,
#    22.0,
#    62.0,
#    20.0,
#    4.0,
#    21.0,
#    5.0,
#    11.0],
#   'description': 'Loddefjord',
#   'length': 984.0},
#  {'currentFlow': {'speed': 10.277778,
#    'speedUncapped': 10.277778,
#    'freeFlow': 13.888889,
#    'jamFactor': 2.3,
#    'confidence': 0.99,
#    'traversability': 'open',
#    'subSegments': [{'length': 442.0,
#      'speed': 10.555556,
#      'speedUncapped': 10.555556,
#      'freeFlow': 14.444445,
#      'jamFactor': 2.3,
#      'confidence': 0.99,
#      'traversability': 'open'},
#     {'length': 26.0,
#      'speed': 6.111111,
#      'speedUncapped': 6.111111,
#      'freeFlow': 8.888889,
#      'jamFactor': 2.7,
#      'confidence': 0.99,
#      'traversability': 'open'}]},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.21772, 60.37007], [5.21746, 60.3702], [5.21726, 60.37031], [5.217, 60.37044], [5.21677, 60.37053], [5.21658, 60.3706], [5.21641, 60.37065], [5.21624, 60.37069]], "type": "LineString"}, {"coordinates": [[5.21624, 60.37069], [5.2161, 60.37072], [5.21598, 60.37074], [5.21584, 60.37076], [5.21562, 60.37077], [5.2154, 60.37077], [5.21521, 60.37076], [5.21496, 60.37074], [5.21463, 60.3707], [5.21458, 60.3707]], "type": "LineString"}, {"coordinates": [[5.21458, 60.3707], [5.21438, 60.37068], [5.2141, 60.37067], [5.21388, 60.37068], [5.21372, 60.3707], [5.21354, 60.37073], [5.21337, 60.37077], [5.21323, 60.37081], [5.21308, 60.37088]], "type": "LineString"}, {"coordinates": [[5.21308, 60.37088], [5.21294, 60.37096], [5.21284, 60.37103], [5.21275, 60.37113], [5.21268, 60.37123], [5.21264, 60.37134], [5.21262, 60.37144], [5.21261, 60.37151]], "type": "LineString"}, {"coordinates": [[5.21261, 60.37151], [5.21261, 60.37153], [5.21261, 60.37161], [5.21262, 60.37175], [5.21264, 60.37187]], "type": "LineString"}, {"coordinates": [[5.21264, 60.37187], [5.21267, 60.37198], [5.21271, 60.37207], [5.21276, 60.37216]], "type": "LineString"}, {"coordinates": [[5.21276, 60.37216], [5.21281, 60.37219]], "type": "LineString"}, {"coordinates": [[5.21281, 60.37219], [5.21283, 60.37222], [5.21285, 60.37226], [5.21284, 60.3723], [5.21281, 60.37234]], "type": "LineString"}, {"coordinates": [[5.21281, 60.37234], [5.21277, 60.37237]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [108.0, 95.0, 90.0, 77.0, 40.0, 33.0, 4.0, 17.0, 4.0],
#   'description': 'Storavatnet',
#   'length': 468.0},
#  {'currentFlow': {'speed': 22.222223,
#    'speedUncapped': 22.777779,
#    'freeFlow': 22.222223,
#    'jamFactor': 0.0,
#    'confidence': 0.99,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.29703, 60.3812], [5.29081, 60.38145], [5.28177, 60.3818], [5.27652, 60.38201]], "type": "LineString"}, {"coordinates": [[5.27652, 60.38201], [5.2755, 60.38205], [5.27453, 60.38208]], "type": "LineString"}, {"coordinates": [[5.27453, 60.38208], [5.27409, 60.38209], [5.27359, 60.38209], [5.27312, 60.38209]], "type": "LineString"}, {"coordinates": [[5.27312, 60.38209], [5.27279, 60.38208]], "type": "LineString"}, {"coordinates": [[5.27279, 60.38208], [5.2722, 60.38203], [5.27196, 60.38201]], "type": "LineString"}, {"coordinates": [[5.27196, 60.38201], [5.27151, 60.38196], [5.27113, 60.38191], [5.27086, 60.38186], [5.27052, 60.38179], [5.27009, 60.38168], [5.26971, 60.38156]], "type": "LineString"}, {"coordinates": [[5.26971, 60.38156], [5.2694, 60.38144], [5.26911, 60.38131], [5.26884, 60.38117], [5.26846, 60.38094], [5.26814, 60.38074]], "type": "LineString"}, {"coordinates": [[5.26814, 60.38074], [5.2678, 60.38054]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [1145.0, 111.0, 79.0, 18.0, 47.0, 136.0, 127.0, 29.0],
#   'description': 'Lyngbø',
#   'length': 1692.0},
#  {'currentFlow': {'speed': 13.611112,
#    'speedUncapped': 13.611112,
#    'freeFlow': 13.333334,
#    'jamFactor': 0.0,
#    'confidence': 0.73,
#    'traversability': 'open',
#    'subSegments': [{'length': 2071.0,
#      'speed': 13.611112,
#      'speedUncapped': 13.888889,
#      'freeFlow': 13.611112,
#      'jamFactor': 0.0,
#      'confidence': 0.73,
#      'traversability': 'open'},
#     {'length': 57.0,
#      'speed': 9.166667,
#      'speedUncapped': 9.166667,
#      'freeFlow': 8.333334,
#      'jamFactor': 0.0,
#      'confidence': 0.73,
#      'traversability': 'open'}]},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5
 60.36689], [5.14676, 60.36698], [5.14717, 60.3671], [5.1475, 60.36721], [5.14789, 60.36736], [5.14823, 60.36751], [5.1485, 60.36765], [5.14897, 60.36796], [5.14921, 60.36813], [5.14944, 60.36831], [5.14967, 60.3685], [5.14994, 60.36874]], "type": "LineString"}, {"coordinates": [[5.14994, 60.36874], [5.15032, 60.36908], [5.15053, 60.36927], [5.15072, 60.36944], [5.15091, 60.3696]], "type": "LineString"}, {"coordinates": [[5.15091, 60.3696], [5.1511, 60.36975]], "type": "LineString"}, {"coordinates": [[5.1511, 60.36975], [5.15124, 60.36985]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [12.0,
#    31.0,
#    36.0,
#    39.0,
#    22.0,
#    49.0,
#    44.0,
#    74.0,
#    333.0,
#    223.0,
#    57.0,
#    321.0,
#    531.0,
#    110.0,
#    20.0,
#    14.0],
#   'description': 'Knarrvika',
#   'length': 1916.0},
#  {'currentFlow': {'speed': 19.444445,
#    'speedUncapped': 19.444445,
#    'freeFlow': 21.111113,
#    'jamFactor': 0.8,
#    'confidence': 0.8,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.14333, 60.46875], [5.14337, 60.46909], [5.14337, 60.46915]], "type": "LineString"}, {"coordinates": [[5.14337, 60.46915], [5.14338, 60.46941], [5.14334, 60.46974], [5.14328, 60.47001], [5.14321, 60.47023], [5.14308, 60.47051], [5.14295, 60.47074], [5.14279, 60.47098], [5.14259, 60.47124], [5.14224, 60.47168]], "type": "LineString"}, {"coordinates": [[5.14224, 60.47168], [5.14204, 60.47196], [5.14191, 60.47217], [5.14181, 60.47237], [5.14174, 60.47256], [5.14168, 60.47277], [5.14165, 60.473]], "type": "LineString"}, {"coordinates": [[5.14165, 60.473], [5.14166, 60.47334], [5.1417, 60.47356], [5.14177, 60.47379], [5.14186, 60.47398]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [45.0, 291.0, 151.0, 110.0],
#   'description': 'Heiavatnet',
#   'length': 597.0},
#  {'currentFlow': {'speed': 6.388889,
#    'speedUncapped': 6.388889,
#    'freeFlow': 6.388889,
#    'jamFactor': 0.0,
#    'confidence': 0.98,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.32501, 60.39364], [5.325, 60.39368], [5.32501, 60.39373], [5.32504, 60.39379], [5.32512, 60.3939]], "type": "LineString"}, {"coordinates": [[5.32512, 60.3939], [5.32516, 60.39397], [5.32519, 60.39403], [5.3252, 60.39408], [5.32518, 60.39412], [5.32513, 60.39416]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [30.0, 30.0],
#   'description': 'Torget',
#   'length': 60.0},
#  {'currentFlow': {'speed': 19.166668,
#    'speedUncapped': 19.166668,
#    'freeFlow': 19.444445,
#    'jamFactor': 0.1,
#    'confidence': 0.99,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.22528, 60.36928], [5.22494, 60.36921], [5.2247, 60.36917]], "type": "LineString"}, {"coordinates": [[5.2247, 60.36917], [5.22465, 60.36916], [5.22421, 60.3691], [5.22405, 60.36909]], "type": "LineString"}, {"coordinates": [[5.22405, 60.36909], [5.22373, 60.36906], [5.22325, 60.36904], [5.22284, 60.36903]], "type": "LineString"}, {"coordinates": [[5.22284, 60.36903], [5.22232, 60.36904], [5.22186, 60.36906]], "type": "LineString"}, {"coordinates": [[5.22186, 60.36906], [5.22146, 60.3691], [5.22108, 60.36915]], "type": "LineString"}, {"coordinates": [[5.22108, 60.36915], [5.22063, 60.36923], [5.22029, 60.3693], [5.21992, 60.36939], [5.21915, 60.36962], [5.21876, 60.36974]], "type": "LineString"}, {"coordinates": [[5.21876, 60.36974], [5.21845, 60.36984], [5.21798, 60.36999], [5.21772, 60.37007]], "type": "LineString"}, {"coordinates": [[5.21772, 60.37007], [5.21698, 60.37032], [5.21654, 60.37047]], "type": "LineString"}, {"coordinates": [[5.21654, 60.37047], [5.21621, 60.37058], [5.21562, 60.37077]], "type": "LineString"}, {"coordinates": [[5.21562, 60.37077], [5.21531, 60.37088], [5.2149, 60.37101], [5.21443, 60.37115], [5.2141, 60.37125]], "type": "LineString"}, {"coordinates": [[5.2141, 60.37125], [5.21366, 60.37137]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [35.0,
#    37.0,
#    68.0,
#    55.0,
#    45.0,
#    145.0,
#    69.0,
#    79.0,
#    61.0,
#    100.0,
#    28.0],
#   'description': 'Storavatnet',
#   'length': 722.0},
#  {'currentFlow': {'speed': 5.8333335,
#    'speedUncapped': 5.8333335,
#    'freeFlow': 7.2222223,
#    'jamFactor': 1.7,
#    'confidence': 0.75,
#    'traversability': 'open',
#    'subSegments': [{'length': 444.0,
#      'speed': 6.388889,
#      'speedUncapped': 6.388889,
#      'freeFlow': 7.5,
#      'jamFactor': 1.5,
#      'confidence': 0.75,
#      'traversability': 'open'},
#     {'length': 191.0,
#      'speed': 4.7222223,
#      'speedUncapped': 4.7222223,
#      'freeFlow': 6.111111,
#      'jamFactor': 2.1,
#      'confidence': 0.75,
#      'traversability': 'open'}]},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.33294, 60.38263], [5.33299, 60.38267], [5.33308, 60.38274], [5.33316, 60.3828], [5.33328, 60.38288], [5.33337, 60.38294], [5.33346, 60.383], [5.33353, 60.38305]], "type": "LineString"}, {"coordinates": [[5.33353, 60.38305], [5.3336, 60.38311], [5.33365, 60.38316], [5.33369, 60.38321]], "type": "LineString"}, {"coordinates": [[5.33369, 60.38321], [5.33371, 60.38326], [5.33372, 60.3833], [5.33373, 60.38334], [5.33374, 60.3834], [5.33373, 60.38348], [5.33368, 60.38359]], "type": "LineString"}, {"coordinates": [[5.33368, 60.38359], [5.33363, 60.38366], [5.33359, 60.38371], [5.33347, 60.38381], [5.3332, 60.384], [5.33308, 60.3841], [5.33299, 60.38419], [5.33293, 60.38426]], "type": "LineString"}, {"coordinates": [[5.33293, 60.38426], [5.33281, 60.38445], [5.33255, 60.38493]], "type": "LineString"}, {"coordinates": [[5.33255, 60.38493], [5.33227, 60.38591], [5.33219, 60.38617], [5.33215, 60.38626], [5.33209, 60.38636]], "type": "LineString"}, {"coordinates": [[5.33209, 60.38636], [5.33205, 60.38643], [5.33201, 60.38654], [5.33196, 60.38674], [5.33191, 60.38695]], "type": "LineString"}, {"coordinates": [[5.33191, 60.38695], [5.33171, 60.3876], [5.33166, 60.38781]], "type": "LineString"}, {"coordinates": [[5.33166, 60.38781], [5.33166, 60.38787], [5.33168, 60.38793], [5.33172, 60.38797], [5.33182, 60.38804]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length':
, 60.46028]], "type": "LineString"}, {"coordinates": [[5.40492, 60.46028], [5.40475, 60.46027]], "type": "LineString"}, {"coordinates": [[5.40475, 60.46027], [5.40435, 60.46026], [5.40368, 60.46022], [5.40318, 60.46018], [5.40236, 60.46011]], "type": "LineString"}, {"coordinates": [[5.40236, 60.46011], [5.40109, 60.45997], [5.40003, 60.45983], [5.39637, 60.45927]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [26.0,
#    21.0,
#    58.0,
#    68.0,
#    746.0,
#    25.0,
#    80.0,
#    41.0,
#    12.0,
#    17.0,
#    10.0,
#    134.0,
#    346.0],
#   'description': 'Gaupåstunnelen',
#   'length': 1584.0},
#  {'currentFlow': {'speed': 13.888889,
#    'speedUncapped': 13.888889,
#    'freeFlow': 13.888889,
#    'jamFactor': 0.0,
#    'confidence': 0.7,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.5224, 60.37979], [5.52237, 60.37974], [5.52223, 60.37969], [5.522, 60.37968], [5.5219, 60.37968]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [34.0],
#   'description': 'Osavatnet',
#   'length': 34.0},
#  {'currentFlow': {'speed': 15.555556,
#    'speedUncapped': 15.555556,
#    'freeFlow': 16.11111,
#    'jamFactor': 0.4,
#    'confidence': 0.93,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.46422, 60.38038], [5.46404, 60.38025], [5.46374, 60.38004]], "type": "LineString"}, {"coordinates": [[5.46374, 60.38004], [5.46358, 60.37993]], "type": "LineString"}, {"coordinates": [[5.46358, 60.37993], [5.46343, 60.37983]], "type": "LineString"}, {"coordinates": [[5.46343, 60.37983], [5.46184, 60.37877]], "type": "LineString"}, {"coordinates": [[5.46184, 60.37877], [5.46027, 60.37771], [5.45912, 60.37693], [5.45886, 60.37675], [5.45868, 60.37662]], "type": "LineString"}, {"coordinates": [[5.45868, 60.37662], [5.45849, 60.37646], [5.45833, 60.3763], [5.45815, 60.37611], [5.45746, 60.37537]], "type": "LineString"}, {"coordinates": [[5.45746, 60.37537], [5.45733, 60.37529], [5.45727, 60.37522]], "type": "LineString"}, {"coordinates": [[5.45727, 60.37522], [5.45715, 60.37511], [5.45684, 60.37481]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [46.0, 15.0, 14.0, 147.0, 297.0, 155.0, 20.0, 51.0],
#   'description': 'Lone',
#   'length': 745.0},
#  {'currentFlow': {'speed': 8.333334,
#    'speedUncapped': 8.333334,
#    'freeFlow': 9.166667,
#    'jamFactor': 0.8,
#    'confidence': 0.75,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.35926, 60.34748], [5.35933, 60.3475]], "type": "LineString"}, {"coordinates": [[5.35933, 60.3475], [5.35975, 60.34776]], "type": "LineString"}, {"coordinates": [[5.35975, 60.34776], [5.35993, 60.34791], [5.36009, 60.34815]], "type": "LineString"}, {"coordinates": [[5.36009, 60.34815], [5.36024, 60.34836], [5.36025, 60.34849], [5.36023, 60.34876], [5.36009, 60.34922], [5.35996, 60.34962], [5.35954, 60.35048]], "type": "LineString"}, {"coordinates": [[5.35954, 60.35048], [5.35944, 60.35067]], "type": "LineString"}, {"coordinates": [[5.35944, 60.35067], [5.35942, 60.35071], [5.35917, 60.35111]], "type": "LineString"}, {"coordinates": [[5.35917, 60.35111], [5.35
], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [21.0, 27.0, 30.0, 17.0, 13.0],
#   'description': 'Nesttun',
#   'length': 108.0},
#  {'currentFlow': {'speed': 6.9444447,
#    'speedUncapped': 6.9444447,
#    'freeFlow': 7.5,
#    'jamFactor': 0.7,
#    'confidence': 0.9,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.35414, 60.31622], [5.35415, 60.31619], [5.35418, 60.31616], [5.35422, 60.31614], [5.35427, 60.31612], [5.35434, 60.31611]], "type": "LineString"}, {"coordinates": [[5.35434, 60.31611], [5.35441, 60.31611], [5.35446, 60.31612], [5.35449, 60.31613], [5.35454, 60.31615], [5.35457, 60.31617], [5.35459, 60.3162]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [18.0, 19.0],
#   'description': 'Nesttun',
#   'length': 37.0},
#  {'currentFlow': {'speed': 15.833334,
#    'speedUncapped': 15.833334,
#    'freeFlow': 16.38889,
#    'jamFactor': 0.3,
#    'confidence': 0.99,
#    'traversability': 'open',
#    'subSegments': [{'length': 1083.0,
#      'speed': 16.666668,
#      'speedUncapped': 16.666668,
#      'freeFlow': 17.222223,
#      'jamFactor': 0.2,
#      'confidence': 0.99,
#      'traversability': 'open'},
#     {'length': 108.0,
#      'speed': 10.833334,
#      'speedUncapped': 10.833334,
#      'freeFlow': 11.388889,
#      'jamFactor': 0.4,
#      'confidence': 0.99,
#      'traversability': 'open'}]},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
# ...
#   'geometry_length': [20.0, 37.0, 18.0, 16.0, 12.0, 30.0, 20.0, 82.0, 48.0],
#   'description': 'Jon Smørs gate/Strandgaten',
#   'length': 283.0},
#  {'currentFlow': {'speed': 13.055556,
#    'speedUncapped': 13.055556,
#    'freeFlow': 13.333334,
#    'jamFactor': 0.3,
#    'confidence': 0.75,
#    'traversability': 'open',
#    'subSegments': [{'length': 813.0,
#      'speed': 12.777778,
#      'speedUncapped': 12.777778,
#      'freeFlow': 12.5,
#      'jamFactor': 0.0,
#      'confidence': 0.75,
#      'traversability': 'open'},
#     {'length': 162.0,
#      'speed': 9.722222,
#      'speedUncapped': 9.722222,
#      'freeFlow': 8.333334,
#      'jamFactor': 0.0,
#      'confidence': 0.75,
#      'traversability': 'open'},
#     {'length': 2475.0,
#      'speed': 12.777778,
#      'speedUncapped': 12.777778,
#      'freeFlow': 13.055556,
#      'jamFactor': 0.1,
#      'confidence': 0.75,
#      'traversability': 'open'},
#     {'length': 6890.0,
#      'speed': 13.333334,
#      'speedUncapped': 13.333334,
#      'freeFlow': 14.166667,
#      'jamFactor': 0.5,
#      'confidence': 0.75,
#      'traversability': 'open'},
#     {'length': 1340.0,
#      'speed': 11.111112,
#      'speedUncapped': 11.111112,
#      'freeFlow': 12.222222,
#      'jamFactor': 0.6,
#      'confidence': 0.75,
#      'traversability': 'open'}]},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5
[5.51478, 60.52397], [5.51498, 60.52398], [5.51512, 60.524], [5.51524, 60.52405], [5.51536, 60.52412], [5.51554, 60.52426], [5.51567, 60.52433], [5.51585, 60.52439], [5.51614, 60.52446], [5.51638, 60.52452], [5.5166, 60.52458], [5.51683, 60.52466], [5.51696, 60.52472], [5.51712, 60.5248], [5.51731, 60.52493], [5.51751, 60.52503], [5.51765, 60.52508], [5.51781, 60.52511], [5.518, 60.52512], [5.51827, 60.52511], [5.51871, 60.52506], [5.51906, 60.52502], [5.51933, 60.525]], "type": "LineString"}, {"coordinates": [[5.51933, 60.525], [5.51945, 60.52499], [5.51966, 60.52498], [5.51982, 60.52499], [5.51998, 60.52501], [5.52014, 60.52505]], "type": "LineString"}, {"coordinates": [[5.52014, 60.52505], [5.52031, 60.52512], [5.52063, 60.52529], [5.5209, 60.52544], [5.52109, 60.52553], [5.52167, 60.5258], [5.52202, 60.52596], [5.52227, 60.52606], [5.52247, 60.52612]], "typ ...
#   'geometry_length': [15.0,
#    60.0,
#    79.0,
#    43.0,
#    45.0,
#    69.0,
#    49.0,
#    199.0,
#    100.0,
#    153.0,
#    31.0,
#    40.0,
#    24.0,
#    10.0,
#    57.0,
#    29.0,
#    25.0,
#    68.0,
#    14.0,
#    17.0,
#    27.0,
#    317.0,
#    46.0,
#    175.0,
#    245.0,
#    88.0,
#    204.0,
#    30.0,
#    27.0,
#    158.0,
#    82.0,
#    7.0,
#    97.0,
#    25.0,
#    74.0,
#    28.0,
#    81.0,
#    59.0,
#    179.0,
#    178.0,
#    11.0,
#    129.0,
#    57.0,
#    206.0,
#    83.0,
#    474.0,
#    30.0,
#    74.0,
#    124.0,
#    31.0,
#    152.0,
#    155.0,
#    159.0,
#    66.0,
#    111.0,
#    51.0,
#    56.0,
#    101.0,
#    433.0,
#    458.0,
#    114.0,
#    47.0,
#    119.0,
#    77.0,
#    1632.0,
#    245.0,
#    26.0,
#    620.0,
#    228.0,
#    305.0,
#    126.0,
#    83.0,
#    405.0,
#    56.0,
#    41.0,
#    156.0,
#    11.0,
#    54.0,
#    486.0,
#    134.0,
#    69.0,
#    47.0,
#    73.0,
#    139.0,
#    39.0,
#    4.0,
#    33.0,
#    79.0,
#    16.0],
#   'description': 'Fotlandsvåg',
#   'length': 11679.0},
#  {'currentFlow': {'speed': 19.166668,
#    'speedUncapped': 20.0,
#    'freeFlow': 18.333334,
#    'jamFactor': 0.0,
#    'confidence': 0.95,
#    'traversability': 'open',
#    'subSegments': [{'length': 2759.0,
#      'speed': 19.166668,
#      'speedUncapped': 20.0,
#      'freeFlow': 18.61111,
#      'jamFactor': 0.0,
#      'confidence': 0.95,
#      'traversability': 'open'},
#     {'length': 47.0,
#      'speed': 12.5,
#      'speedUncapped': 12.5,
#      'freeFlow': 8.611112,
#      'jamFactor': 0.0,
#      'confidence': 0.95,
#      'traversability': 'open'}]},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5
, 60.41404], [5.46684, 60.41426], [5.46677, 60.41448], [5.46668, 60.41472]], "type": "LineString"}, {"coordinates": [[5.46668, 60.41472], [5.46659, 60.41491], [5.46651, 60.41505], [5.46639, 60.41523]], "type": "LineString"}, {"coordinates": [[5.46639, 60.41523], [5.46624, 60.41543], [5.46605, 60.41564], [5.46587, 60.41582], [5.46563, 60.41604], [5.46543, 60.4162]], "type": "LineString"}, {"coordinates": [[5.46543, 60.4162], [5.46504, 60.41653]], "type": "LineString"}, {"coordinates": [[5.46504, 60.41653], [5.46487, 60.41679], [5.46475, 60.41696]], "type": "LineString"}, {"coordinates": [[5.46475, 60.41696], [5.46477, 60.41699]], "type": "LineString"}, {"coordinates": [[5.46477, 60.41699], [5.46478, 60.41703], [5.46475, 60.41709], [5.46465, 60.41715], [5.46459, 60.41717]], "type": "LineString"}, {"coordinates": [[5.46459, 60.41717], [5.46446, 60.41718]], "type": "LineString"}, {"coordinates": [[5.46446, 60.41718], [5.46435, 60.41716], [5.46426, 60.41713]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [50.0,
#    37.0,
#    111.0,
#    9.0,
#    259.0,
#    31.0,
#    30.0,
#    75.0,
#    46.0,
#    23.0,
#    50.0,
#    38.0,
#    18.0,
#    26.0,
#    49.0,
#    45.0,
#    36.0,
#    42.0,
#    157.0,
#    798.0,
#    394.0,
#    75.0,
#    86.0,
#    59.0,
#    121.0,
#    43.0,
#    50.0,
#    4.0,
#    24.0,
#    7.0,
#    13.0],
#   'description': 'Indre Arna',
#   'length': 2806.0},
#  {'currentFlow': {'speed': 5.0,
#    'speedUncapped': 5.0,
#    'freeFlow': 7.777778,
#    'jamFactor': 2.2,
#    'confidence': 0.98,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.35614, 60.31469], [5.35595, 60.3146], [5.35577, 60.31454]], "type": "LineString"}, {"coordinates": [[5.35577, 60.31454], [5.35572, 60.31452], [5.35544, 60.31446]], "type": "LineString"}, {"coordinates": [[5.35544, 60.31446], [5.35538, 60.3145], [5.35529, 60.31451], [5.3552, 60.3145]], "type": "LineString"}, {"coordinates": [[5.3552, 60.3145], [5.35513, 60.31447], [5.3551, 60.31443], [5.35512, 60.31438], [5.35518, 60.31434]], "type": "LineString"}, {"coordinates": [[5.35518, 60.31434], [5.35531, 60.31433]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [27.0, 21.0, 16.0, 21.0, 7.0],
#   'description': 'Kalandseidet',
#   'length': 92.0},
#  {'currentFlow': {'speed': 10.833334,
#    'speedUncapped': 10.833334,
#    'freeFlow': 10.555556,
#    'jamFactor': 0.0,
#    'confidence': 0.86,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.23285, 60.41287], [5.23173, 60.4127]], "type": "LineString"}, {"coordinates": [[5.23173, 60.4127], [5.23109, 60.4126]], "type": "LineString"}, {"coordinates": [[5.23109, 60.4126], [5.23062, 60.41252], [5.23042, 60.41248], [5.23026, 60.41244], [5.23009, 60.41239]], "type": "LineString"}, {"coordinates": [[5.23009, 60.41239], [5.22984, 60.4123], [5.22964, 60.41221], [5.22946, 60.41211], [5.22927, 60.41198]], "type": "LineString"}, {"coordinates": [[5.22927, 60.41198], [5.22913, 60.41188]], "type": "LineString"}, {"coordinates": [[5.22913, 60.41188], [5.22907, 60.41184]], "type": "LineString"}, {"coordinates": [[5.22907, 60.41184], [5.22899, 60.41181], [5.22892, 60.41178], [5.22882, 60.41172]], "type": "LineString"}, {"coordinates": [[5.22882, 60.41172], [5.22875, 60.41168], [5.22866, 60.41164], [5.22855, 60.4116], [5.22845, 60.41157]], "type": "LineString"}, {"coordinates": [[5.22845, 60.41157], [5.22839, 60.41157], [5.22832, 60.41156]], "type": "LineString"}, {"coordinates": [[5.22832, 60.41156], [5.22828, 60.41155], [5.22823, 60.41153], [5.22818, 60.4115], [5.22815, 60.41147], [5.22813, 60.41143]], "type": "LineString"}, {"coordinates": [[5.22813, 60.41143], [5.22813, 60.4114]], "type": "LineString"}, {"coordinates": [[5.22813, 60.4114], [5.22814, 60.41137], [5.22816, 60.41134]], "type": "LineString"}, {"coordinates": [[5.22816, 60.41134], [5.2282, 60.41131]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [65.0,
#    37.0,
#    61.0,
#    65.0,
#    14.0,
#    6.0,
#    19.0,
#    27.0,
#    7.0,
#    19.0,
#    3.0,
#    7.0,
#    4.0],
#   'description': 'Strand',
#   'length': 334.0},
#  {'currentFlow': {'speed': 16.666668,
#    'speedUncapped': 18.055555,
#    'freeFlow': 16.666668,
#    'jamFactor': 0.0,
#    'confidence': 0.87,
#    'traversability': 'open'},
#   'sourceUpdated': datetime.datetime(2023, 4, 20, 5, 28, 9, tzinfo=tzutc()),
#   'api_call_time': datetime.datetime(2023, 4, 20, 7, 30, tzinfo=<DstTzInfo 'Europe/Oslo' CEST+2:00:00 DST>),
#   'geometry': {"geometries": [{"coordinates": [[5.53675, 60.43188], [5.53631, 60.43144], [5.53615, 60.43128]], "type": "LineString"}, {"coordinates": [[5.53615, 60.43128], [5.536, 60.43117], [5.53571, 60.43091], [5.53568, 60.43089]], "type": "LineString"}, {"coordinates": [[5.53568, 60.43089], [5.53547, 60.4307], [5.53509, 60.43037]], "type": "LineString"}], "type": "GeometryCollection"},
#   'geometry_length': [75.0, 51.0, 66.0],
#   'description': 'Osterøy bomstasjon',
#   'length': 192.0}]

# %%
def insert_raw_data(urls: list, db_name: str, day: str):
    # retrieve database and collections wrappers
    db, collections = retrieve_database_and_collections(db_name, day, ["raw", "processed"])
    empty_collections = take_empty_collections(collections)
    
    # load the raw data
    raw_data = load_raw_data(urls)
    
    # insert the documents in the collections
    for key, value in empty_collections.items():
        if "raw" in key:
            value.insert_many(list(raw_data.values()))
        else:
            pass

# %%
def insert_processed_data(processed_data: dict, db_name: str, day: str):
    # retrieve database and collections wrappers
    db, collections = retrieve_database_and_collections(db_name, day, ["raw", "processed"])
    empty_collections = take_empty_collections(collections)
    
    # insert the documents in the collections
    for key, value in empty_collections.items():
        if "raw" in key:
            pass
        elif "processed" in key:
            value.insert_many(list(processed_data))

# %% [markdown]
# Insert the data in the collections

# %%
insert_raw_data(urls, db_name, days)
insert_processed_data(processed_data, db_name, days)
