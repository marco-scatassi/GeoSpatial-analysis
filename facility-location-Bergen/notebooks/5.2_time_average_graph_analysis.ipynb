# %% [markdown]
# ## Import

# %%
import sys
sys.path.append(r'C:\Users\Marco\Documents\GitHub\GeoSpatial-analysis\facility-location-Bergen\src\facility_location_Bergen\custome_modules')

# %%
import warnings
from shapely.errors import ShapelyDeprecationWarning
# Ignore the ShapelyDeprecationWarning
warnings.filterwarnings("ignore", category=ShapelyDeprecationWarning)

# %%
import pytz
import folium
import numpy as np
import pickle as pkl
from PIL import Image
import networkx as nx
import geopandas as gpd
import cartopy.crs as ccrs
from datetime import datetime
import matplotlib.pyplot as plt
import cartopy.io.img_tiles as cimgt
from urllib.request import urlopen, Request
from matplotlib.animation import FuncAnimation
from mongo_db import retrieve_database_and_collections
from networkx.drawing.nx_agraph import graphviz_layout
from convert_geometry import toMultiLineString, toExtremePoints

# %% [markdown]
# ## Retrieve collection and convert to a dataframe

# %%
day = "20_04_2023"

# %%
with open(rf"C:\Users\Marco\Documents\GitHub\GeoSpatial-analysis\facility-location-Bergen\data\03_primary\{day}.geojson", "rb") as f:
    gdf = pkl.load(f)

# %%
gdf = gdf.set_geometry("geometry.extreme_point")

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Find unique identifier for road segments

# %%
for date in gdf["api_call_time"].unique():
    sub_gdf = gdf[gdf["api_call_time"] == date]
    key = sub_gdf["geometry.extreme_point"]
    print(date, len(sub_gdf), len(key.unique()), len(sub_gdf)-len(key.unique()))
# Out:
# 2023-04-20 13:00:00+00:00 620 616 4
# 2023-04-20 13:05:00+00:00 622 618 4
# 2023-04-20 13:10:00+00:00 624 620 4
# 2023-04-20 13:15:00+00:00 626 622 4
# 2023-04-20 13:20:00+00:00 624 620 4
# 2023-04-20 13:25:00+00:00 625 621 4
# 2023-04-20 13:30:00+00:00 623 619 4
# 2023-04-20 13:35:00+00:00 620 616 4
# 2023-04-20 13:40:00+00:00 623 619 4
# 2023-04-20 13:45:00+00:00 623 619 4
# 2023-04-20 13:50:00+00:00 627 623 4
# 2023-04-20 13:55:00+00:00 621 617 4
# 2023-04-20 14:00:00+00:00 628 624 4
# 2023-04-20 14:05:00+00:00 624 620 4
# 2023-04-20 14:10:00+00:00 625 621 4
# 2023-04-20 14:15:00+00:00 623 619 4
# 2023-04-20 14:20:00+00:00 625 621 4
# 2023-04-20 14:25:00+00:00 622 618 4
# 2023-04-20 14:30:00+00:00 625 621 4
# 2023-04-20 14:35:00+00:00 622 618 4
# 2023-04-20 14:40:00+00:00 622 618 4
# 2023-04-20 14:45:00+00:00 623 619 4
# 2023-04-20 14:50:00+00:00 623 619 4
# 2023-04-20 14:55:00+00:00 626 622 4
# 2023-04-20 15:00:00+00:00 624 620 4
# 2023-04-20 09:00:00+00:00 619 615 4
# 2023-04-20 09:05:00+00:00 620 616 4
# 2023-04-20 09:10:00+00:00 620 616 4
# 2023-04-20 09:15:00+00:00 618 614 4
# 2023-04-20 09:20:00+00:00 618 614 4
# 2023-04-20 09:25:00+00:00 617 613 4
# 2023-04-20 09:30:00+00:00 616 612 4
# 2023-04-20 09:35:00+00:00 617 613 4
# 2023-04-20 09:40:00+00:00 616 612 4
# 2023-04-20 09:45:00+00:00 618 614 4
# 2023-04-20 09:50:00+00:00 617 613 4
# 2023-04-20 09:55:00+00:00 618 614 4
# 2023-04-20 10:00:00+00:00 617 613 4
# 2023-04-20 05:30:00+00:00 619 615 4
# 2023-04-20 05:35:00+00:00 618 614 4
# 2023-04-20 05:40:00+00:00 619 615 4
# 2023-04-20 05:45:00+00:00 620 616 4
# 2023-04-20 05:50:00+00:00 618 614 4
# 2023-04-20 05:55:00+00:00 617 613 4
# 2023-04-20 06:00:00+00:00 619 615 4
# 2023-04-20 06:05:00+00:00 618 614 4
# 2023-04-20 06:10:00+00:00 620 616 4
# 2023-04-20 06:15:00+00:00 620 616 4
# 2023-04-20 06:20:00+00:00 621 617 4
# 2023-04-20 06:25:00+00:00 621 617 4
# 2023-04-20 06:30:00+00:00 620 616 4
# 2023-04-20 06:35:00+00:00 623 619 4
# 2023-04-20 06:40:00+00:00 620 616 4
# 2023-04-20 06:45:00+00:00 620 616 4
# 2023-04-20 06:50:00+00:00 621 617 4
# 2023-04-20 06:55:00+00:00 620 616 4
# 2023-04-20 07:00:00+00:00 620 616 4
# 2023-04-20 07:05:00+00:00 620 616 4
# 2023-04-20 07:10:00+00:00 620 616 4
# 2023-04-20 07:15:00+00:00 618 614 4
# 2023-04-20 07:20:00+00:00 618 614 4
# 2023-04-20 07:25:00+00:00 618 614 4
# 2023-04-20 07:30:00+00:00 618 614 4

# %%
for date in list(gdf["api_call_time"].unique()):
    sub_gdf = gdf[(gdf["api_call_time"] == date)]
    vc = sub_gdf["geometry.extreme_point"].value_counts(sort=False)
    sub_sub_gdf = sub_gdf[sub_gdf["geometry.extreme_point"].isin(vc[vc > 1].index)]
    for geometry in sub_sub_gdf["geometry.extreme_point"].unique():
        print("the description field is different: ", len(sub_sub_gdf[sub_sub_gdf["geometry.extreme_point"] == geometry]["description"].unique())>1)
        if len(sub_sub_gdf[sub_sub_gdf["geometry.extreme_point"] == geometry]["description"].unique())<2:
            print(date)
            break
# Out:
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True
# the description field is different:  True

# %% [markdown]
# From the previous cells we observe that the tuple ("description, "geometry") is unique for each road segment. We can therefore use this tuple as a unique identifier for each road segment.

# %% [markdown]
# ### Split gdf according to time

# %%
first_morning_date = datetime.strptime("2023-04-20T07:30:00+02:00", "%Y-%m-%dT%H:%M:%S%z")
last_morning_date = datetime.strptime("2023-04-20T09:30:00+02:00", "%Y-%m-%dT%H:%M:%S%z")

# %%
gdf_morning = gdf[(gdf["api_call_time"] >= first_morning_date) & (gdf["api_call_time"] <= last_morning_date)]

# %%
first_midday_date = datetime.strptime("2023-04-20T11:00:00+02:00", "%Y-%m-%dT%H:%M:%S%z")
last_midday_date = datetime.strptime("2023-04-20T12:00:00+02:00", "%Y-%m-%dT%H:%M:%S%z")

# %%
gdf_midday = gdf[(gdf["api_call_time"] >= first_midday_date) & (gdf["api_call_time"] <= last_midday_date)]

# %%
first_afternoon_date = datetime.strptime("2023-04-20T15:00:00+02:00", "%Y-%m-%dT%H:%M:%S%z")
last_afternoon_date = datetime.strptime("2023-04-20T17:00:00+02:00", "%Y-%m-%dT%H:%M:%S%z")

# %%
gdf_afternoon = gdf[(gdf["api_call_time"] >= first_afternoon_date) & (gdf["api_call_time"] <= last_afternoon_date)]

# %% [markdown]
# ### Take average value in each road segment for each gdf

# %% [markdown]
# #### Morning

# %%
gdf.columns
# Out:
# Index(['sourceUpdated', 'api_call_time', 'description', 'length',
#        'currentFlow.speed', 'currentFlow.speedUncapped',
#        'currentFlow.freeFlow', 'currentFlow.jamFactor',
#        'currentFlow.confidence', 'currentFlow.traversability', 'geometry.type',
#        'currentFlow.jamTendency', 'currentFlow.junctionTraversability',
#        'geometry.multi_line', 'geometry.extreme_point'],
#       dtype='object')

# %%
gdf_morning_average = gdf_morning.groupby(["description", "geometry.extreme_point"], sort=False, dropna=False)[['length',
       'currentFlow.speed', 'currentFlow.speedUncapped',
       'currentFlow.freeFlow', 'currentFlow.jamFactor',
       'currentFlow.confidence']].mean().reset_index()

# %%
gdf_morning_average
# Out:
#       description                           geometry.extreme_point  length
# 0         Herland  MULTIPOINT (5.53747 60.42335, 5.53903 60.42214)   374.0  \
# 1         Herland  MULTIPOINT (5.53492 60.42177, 5.53757 60.42317)   313.0
# 2          Takvam  MULTIPOINT (5.53492 60.42177, 5.51596 60.42212)  1173.0
# 3          Takvam  MULTIPOINT (5.46050 60.42195, 5.51596 60.42212)  8122.0
# 4          Takvam  MULTIPOINT (5.51612 60.42207, 5.51624 60.42231)    31.0
# ..            ...                                              ...     ...
# 628        Salhus  MULTIPOINT (5.26737 60.50590, 5.26773 60.50591)    20.0
# 629     Smedneset  MULTIPOINT (5.26722 60.50718, 5.26710 60.50710)    12.0
# 630        Salhus  MULTIPOINT (5.26710 60.50710, 5.26737 60.50590)   134.0
# 631     Smedneset  MULTIPOINT (5.26737 60.50590, 5.26722 60.50718)   146.0
# 632  Steinstø kai  MULTIPOINT (5.31857 60.52310, 5.31921 60.52286)    44.0
#
#      currentFlow.speed  currentFlow.speedUncapped  currentFlow.freeFlow
# 0            12.300000                  12.300000             16.111110  \
# 1            15.344445                  15.344445             15.000000
# 2            19.066667                  19.244445             19.444445
# 3            11.344445                  11.344445             12.222222
# 4             6.344444                   6.344444              8.611112
# ..                 ...                        ...                   ...
# 628           7.777778                   7.777778              7.777778
# 629           4.166667                   4.166667              4.166667
# 630           6.377778                   6.377778              7.777778
# 631           4.722222                   4.722222              5.277778
# 632           5.977778                   5.977778              6.111111
#
#      currentFlow.jamFactor  currentFlow.confidence
# 0                    1.912                  0.7536
# 1                    0.096                  0.7708
# 2                    0.164                  0.8996
# 3                    0.596                  0.8144
# 4                    2.144                  0.7276
# ..                     ...                     ...
# 628                  0.000                  0.7072
# 629                  0.000                  0.7000
# 630                  1.572                  0.7000
# 631                  0.800                  0.7000
# 632                  0.192                  0.7000
#
# [633 rows x 8 columns]

# %% [markdown]
# ##### Check for the presence of NaN values

# %%
gdf_morning_average[gdf_morning_average.isna().apply(lambda x: x["currentFlow.speedUncapped"], axis=1)]
# Out:
#      description                           geometry.extreme_point  length
# 189          NaN  MULTIPOINT (5.33799 60.32356, 5.34689 60.31863)  1374.0  \
# 300  Myraskjenet  MULTIPOINT (5.21953 60.34025, 5.19267 60.34695)  3273.0
# 327       Nyborg  MULTIPOINT (5.19267 60.34695, 5.19708 60.37056)  2727.0
#
#      currentFlow.speed  currentFlow.speedUncapped  currentFlow.freeFlow
# 189                NaN                        NaN              7.222222  \
# 300                NaN                        NaN             12.222222
# 327                NaN                        NaN             12.222222
#
#      currentFlow.jamFactor  currentFlow.confidence
# 189                   10.0                     NaN
# 300                   10.0                     NaN
# 327                   10.0                     NaN

# %% [markdown]
# ##### Delete NaN values

# %%
gdf_morning_average.dropna(subset=["currentFlow.speedUncapped"], inplace=True)

# %%
gdf_morning_average[gdf_morning_average.isna().apply(lambda x: x["currentFlow.speedUncapped"], axis=1)]
# Out:
# Empty DataFrame
# Columns: [description, geometry.extreme_point, length, currentFlow.speed, currentFlow.speedUncapped, currentFlow.freeFlow, currentFlow.jamFactor, currentFlow.confidence]
# Index: []

# %% [markdown]
# #### Midday

# %%
gdf.columns
# Out:
# Index(['sourceUpdated', 'api_call_time', 'description', 'length',
#        'currentFlow.speed', 'currentFlow.speedUncapped',
#        'currentFlow.freeFlow', 'currentFlow.jamFactor',
#        'currentFlow.confidence', 'currentFlow.traversability', 'geometry.type',
#        'currentFlow.jamTendency', 'currentFlow.junctionTraversability',
#        'geometry.multi_line', 'geometry.extreme_point'],
#       dtype='object')

# %%
gdf_midday_average = gdf_midday.groupby(["description", "geometry.extreme_point"], sort=False, dropna=False)[['length',
       'currentFlow.speed', 'currentFlow.speedUncapped',
       'currentFlow.freeFlow', 'currentFlow.jamFactor',
       'currentFlow.confidence']].mean().reset_index()

# %%
gdf_midday_average
# Out:
#       description                           geometry.extreme_point  length
# 0         Herland  MULTIPOINT (5.53747 60.42335, 5.53903 60.42214)   374.0  \
# 1         Herland  MULTIPOINT (5.53492 60.42177, 5.53757 60.42317)   313.0
# 2          Takvam  MULTIPOINT (5.53492 60.42177, 5.51596 60.42212)  1173.0
# 3          Takvam  MULTIPOINT (5.51612 60.42207, 5.51624 60.42231)    31.0
# 4          Takvam  MULTIPOINT (5.46050 60.42195, 5.51596 60.42212)  8122.0
# ..            ...                                              ...     ...
# 620        Salhus  MULTIPOINT (5.26710 60.50710, 5.26737 60.50590)   134.0
# 621     Smedneset  MULTIPOINT (5.26737 60.50590, 5.26722 60.50718)   146.0
# 622     Smedneset  MULTIPOINT (5.26722 60.50718, 5.26710 60.50710)    12.0
# 623        Salhus  MULTIPOINT (5.26737 60.50590, 5.26773 60.50591)    20.0
# 624  Steinstø kai  MULTIPOINT (5.31857 60.52310, 5.31921 60.52286)    44.0
#
#      currentFlow.speed  currentFlow.speedUncapped  currentFlow.freeFlow
# 0            12.863248                  12.863248             16.111110  \
# 1            14.358975                  14.358975             15.000000
# 2            19.209402                  19.615385             19.444445
# 3             5.619658                   5.619658              8.611112
# 4            10.940172                  10.940172             12.222222
# ..                 ...                        ...                   ...
# 620           5.555556                   5.555556              7.777778
# 621           4.722222                   4.722222              5.277778
# 622           4.166667                   4.166667              4.166667
# 623           7.799145                   7.799145              7.777778
# 624           5.576924                   5.576924              6.111111
#
#      currentFlow.jamFactor  currentFlow.confidence
# 0                 1.738462                0.720769
# 1                 0.346154                0.736154
# 2                 0.092308                0.870000
# 3                 2.707692                0.706154
# 4                 0.876923                0.826154
# ..                     ...                     ...
# 620               2.500000                0.700000
# 621               0.800000                0.700000
# 622               0.000000                0.700000
# 623               0.000000                0.708462
# 624               0.769231                0.700000
#
# [625 rows x 8 columns]

# %% [markdown]
# ##### Check for the presence of NaN values

# %%
gdf_midday_average[gdf_midday_average.isna().apply(lambda x: x["currentFlow.speedUncapped"], axis=1)]
# Out:
#      description                           geometry.extreme_point  length
# 188          NaN  MULTIPOINT (5.33799 60.32356, 5.34689 60.31863)  1374.0  \
# 189          NaN  MULTIPOINT (5.33952 60.31717, 5.33961 60.31630)   106.0
# 300  Myraskjenet  MULTIPOINT (5.21953 60.34025, 5.19267 60.34695)  3273.0
# 325       Nyborg  MULTIPOINT (5.19267 60.34695, 5.19708 60.37056)  2727.0
#
#      currentFlow.speed  currentFlow.speedUncapped  currentFlow.freeFlow
# 188                NaN                        NaN              7.222222  \
# 189                NaN                        NaN              0.000000
# 300                NaN                        NaN             12.222222
# 325                NaN                        NaN             12.222222
#
#      currentFlow.jamFactor  currentFlow.confidence
# 188                   10.0                     NaN
# 189                   10.0                     NaN
# 300                   10.0                     NaN
# 325                   10.0                     NaN

# %% [markdown]
# ##### Delete NaN values

# %%
gdf_midday_average.dropna(subset=["currentFlow.speedUncapped"], inplace=True)

# %%
gdf_midday_average[gdf_midday_average.isna().apply(lambda x: x["currentFlow.speedUncapped"], axis=1)]
# Out:
# Empty DataFrame
# Columns: [description, geometry.extreme_point, length, currentFlow.speed, currentFlow.speedUncapped, currentFlow.freeFlow, currentFlow.jamFactor, currentFlow.confidence]
# Index: []

# %% [markdown]
# #### Afternoon

# %%
gdf.columns
# Out:
# Index(['sourceUpdated', 'api_call_time', 'description', 'length',
#        'currentFlow.speed', 'currentFlow.speedUncapped',
#        'currentFlow.freeFlow', 'currentFlow.jamFactor',
#        'currentFlow.confidence', 'currentFlow.traversability', 'geometry.type',
#        'currentFlow.jamTendency', 'currentFlow.junctionTraversability',
#        'geometry.multi_line', 'geometry.extreme_point'],
#       dtype='object')

# %%
gdf_afternoon_average = gdf_afternoon.groupby(["description", "geometry.extreme_point"], sort=False, dropna=False)[['length',
       'currentFlow.speed', 'currentFlow.speedUncapped',
       'currentFlow.freeFlow', 'currentFlow.jamFactor',
       'currentFlow.confidence']].mean().reset_index()

# %%
gdf_afternoon_average
# Out:
#       description                           geometry.extreme_point  length
# 0         Herland  MULTIPOINT (5.53747 60.42335, 5.53903 60.42214)   374.0  \
# 1         Herland  MULTIPOINT (5.53492 60.42177, 5.53757 60.42317)   313.0
# 2          Takvam  MULTIPOINT (5.53492 60.42177, 5.51596 60.42212)  1173.0
# 3          Takvam  MULTIPOINT (5.51612 60.42207, 5.51624 60.42231)    31.0
# 4          Takvam  MULTIPOINT (5.46050 60.42195, 5.51596 60.42212)  8122.0
# ..            ...                                              ...     ...
# 654     Smedneset  MULTIPOINT (5.26722 60.50718, 5.26710 60.50710)    12.0
# 655     Smedneset  MULTIPOINT (5.26737 60.50590, 5.26722 60.50718)   146.0
# 656        Salhus  MULTIPOINT (5.26710 60.50710, 5.26737 60.50590)   134.0
# 657        Salhus  MULTIPOINT (5.26737 60.50590, 5.26773 60.50591)    20.0
# 658  Steinstø kai  MULTIPOINT (5.31857 60.52310, 5.31921 60.52286)    44.0
#
#      currentFlow.speed  currentFlow.speedUncapped  currentFlow.freeFlow
# 0            13.755556                  13.755556             16.111110  \
# 1            15.333334                  15.366667             15.000000
# 2            19.344445                  19.744445             19.444445
# 3             5.766667                   5.766667              8.611112
# 4            11.044445                  11.044445             12.222222
# ..                 ...                        ...                   ...
# 654           4.122223                   4.122223              4.166667
# 655           4.244445                   4.244445              5.277778
# 656           5.522223                   5.522223              7.777778
# 657           7.611111                   7.611111              7.777778
# 658           4.677778                   4.677778              6.111111
#
#      currentFlow.jamFactor  currentFlow.confidence
# 0                    1.244                  0.7220
# 1                    0.148                  0.8708
# 2                    0.040                  0.9388
# 3                    2.484                  0.7172
# 4                    0.796                  0.8792
# ..                     ...                     ...
# 654                  0.000                  0.7016
# 655                  0.512                  0.7216
# 656                  2.460                  0.7016
# 657                  0.188                  0.7180
# 658                  1.792                  0.7028
#
# [659 rows x 8 columns]

# %% [markdown]
# ##### Check for the presence of NaN values

# %%
gdf_afternoon_average[gdf_afternoon_average.isna().apply(lambda x: x["currentFlow.speedUncapped"], axis=1)]
# Out:
#      description                           geometry.extreme_point  length
# 65           NaN  MULTIPOINT (5.28976 60.29086, 5.29016 60.29079)    24.0  \
# 66           NaN  MULTIPOINT (5.29016 60.29079, 5.29048 60.29037)    58.0
# 67           NaN  MULTIPOINT (5.29048 60.29037, 5.29046 60.29013)    27.0
# 193          NaN  MULTIPOINT (5.33799 60.32356, 5.34689 60.31863)  1374.0
# 194          NaN  MULTIPOINT (5.33952 60.31717, 5.33961 60.31630)   106.0
# 310  Myraskjenet  MULTIPOINT (5.21953 60.34025, 5.19267 60.34695)  3273.0
# 334       Nyborg  MULTIPOINT (5.19267 60.34695, 5.19708 60.37056)  2727.0
#
#      currentFlow.speed  currentFlow.speedUncapped  currentFlow.freeFlow
# 65                 NaN                        NaN              0.000000  \
# 66                 NaN                        NaN              0.000000
# 67                 NaN                        NaN              0.000000
# 193                NaN                        NaN              7.222222
# 194                NaN                        NaN              0.000000
# 310                NaN                        NaN             12.222222
# 334                NaN                        NaN             12.222222
#
#      currentFlow.jamFactor  currentFlow.confidence
# 65                    10.0                     NaN
# 66                    10.0                     NaN
# 67                    10.0                     NaN
# 193                   10.0                     NaN
# 194                   10.0                     NaN
# 310                   10.0                     NaN
# 334                   10.0                     NaN

# %% [markdown]
# ##### Delete NaN values

# %%
gdf_afternoon_average.dropna(subset=["currentFlow.speedUncapped"], inplace=True)

# %%
gdf_afternoon_average[gdf_afternoon_average.isna().apply(lambda x: x["currentFlow.speedUncapped"], axis=1)]
# Out:
# Empty DataFrame
# Columns: [description, geometry.extreme_point, length, currentFlow.speed, currentFlow.speedUncapped, currentFlow.freeFlow, currentFlow.jamFactor, currentFlow.confidence]
# Index: []

# %% [markdown]
# ## Build average graph

# %% [markdown]
# ### Morning
